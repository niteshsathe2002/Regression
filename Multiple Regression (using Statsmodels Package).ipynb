# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
df=pd.read_csv("C:\DATA\Book1.csv")

# %%
df.head()
# Out:
#    R&D_Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.size
# Out:
# 250

# %%
df.shape
# Out:
# (50, 5)

# %%
df.isnull().sum()*100/df.shape[0]
# Out:
# R&D Spend          0.0
# Administration     0.0
# Marketing Spend    0.0
# State              0.0
# Profit             0.0
# dtype: float64

# %%
df.dtypes
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %%
df.drop("State",axis=1).describe()
# Out:
#            R&D_Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
plt.figure(figsize=(4,4))
sns.pairplot(df.drop("State",axis=1))

# %%
plt.boxplot(df.drop("State",axis=1))
plt.show()

# %%
x=df.iloc[:,:3]
y=df.iloc[:,4]

# %%
x=sm.add_constant(x)
model=sm.OLS(y,x).fit()
model.summary()
model2=sm.OLS(y,)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Fri, 21 Jul 2023   Prob (F-statistic):           4.53e-30
# Time:                        15:11:01   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %% [markdown]
# conclusion:
#            1.We observed the p_value on above table and conclude that a least one Regressor contribute significantly in the model.
#            2.The Regressor "R&D Spend" contribute significantly in the model.
#            3.Adj. R-squared:	0.948 is means that the 94.8% varibiltity explain by given fittef model

# %% [markdown]
# #### Residual plots

# %%
fig=plt.figure(figsize=(8,8))
sm.graphics.plot_regress_exog(model,'R&D_Spend',fig=fig)
